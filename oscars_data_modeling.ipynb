# %%
import pandas as pd
import numpy as np

from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.ensemble import VotingClassifier, RandomForestClassifier
from sklearn.linear_model import LogisticRegression

from xgboost import XGBClassifier

# %%
oscar_winners = pd.read_csv('/Users/paulettedvm/Downloads/the_oscar_award.csv')
oscar_winners
# Out:
#        year_film  year_ceremony  ceremony                          category  \
# 0           1927           1928         1                             ACTOR
# 1           1927           1928         1                             ACTOR
# 2           1927           1928         1                           ACTRESS
# 3           1927           1928         1                           ACTRESS
# 4           1927           1928         1                           ACTRESS
# ...          ...            ...       ...                               ...
# 10884       2023           2024        96     WRITING (Original Screenplay)
# 10885       2023           2024        96  JEAN HERSHOLT HUMANITARIAN AWARD
# 10886       2023           2024        96                    HONORARY AWARD
# 10887       2023           2024        96                    HONORARY AWARD
# 10888       2023           2024        96                    HONORARY AWARD
#
#                                                     name              film  \
# 0                                    Richard Barthelmess         The Noose
# 1                                          Emil Jannings  The Last Command
# 2                                         Louise Dresser   A Ship Comes In
# 3                                           Janet Gaynor        7th Heaven
# 4                                         Gloria Swanson    Sadie Thompson
# ...                                                  ...               ...
# 10884                             Written by Celine Song        Past Lives
# 10885                                                NaN               NaN
# 10886  To Angela Bassett, who has inspired audiences ...               NaN
# 10887  To Mel Brooks, for his comedic brilliance, pro...               NaN
# 10888  To Carol Littleton, whose commitment to her cr...               NaN
#
#        winner
# 0       False
# 1        True
# 2       False
# 3        True
# 4       False
# ...       ...
# 10884   False
# 10885    True
# 10886    True
# 10887    True
# 10888    True
#
# [10889 rows x 7 columns]

# %%
# cut the data so that 'year_film' is 2000-2023

oscar_winners_2000_2023 = oscar_winners[oscar_winners['year_film'] >= 2000]
oscar_winners_2000_2023
# Out:
#        year_film  year_ceremony  ceremony                          category  \
# 8007        2000           2001        73           ACTOR IN A LEADING ROLE
# 8008        2000           2001        73           ACTOR IN A LEADING ROLE
# 8009        2000           2001        73           ACTOR IN A LEADING ROLE
# 8010        2000           2001        73           ACTOR IN A LEADING ROLE
# 8011        2000           2001        73           ACTOR IN A LEADING ROLE
# ...          ...            ...       ...                               ...
# 10884       2023           2024        96     WRITING (Original Screenplay)
# 10885       2023           2024        96  JEAN HERSHOLT HUMANITARIAN AWARD
# 10886       2023           2024        96                    HONORARY AWARD
# 10887       2023           2024        96                    HONORARY AWARD
# 10888       2023           2024        96                    HONORARY AWARD
#
#                                                     name                film  \
# 8007                                       Javier Bardem  Before Night Falls
# 8008                                       Russell Crowe           Gladiator
# 8009                                           Tom Hanks           Cast Away
# 8010                                           Ed Harris             Pollock
# 8011                                       Geoffrey Rush              Quills
# ...                                                  ...                 ...
# 10884                             Written by Celine Song          Past Lives
# 10885                                                NaN                 NaN
# 10886  To Angela Bassett, who has inspired audiences ...                 NaN
# 10887  To Mel Brooks, for his comedic brilliance, pro...                 NaN
# 10888  To Carol Littleton, whose commitment to her cr...                 NaN
#
#        winner
# 8007    False
# 8008     True
# 8009    False
# 8010    False
# 8011    False
# ...       ...
# 10884   False
# 10885    True
# 10886    True
# 10887    True
# 10888    True
#
# [2882 rows x 7 columns]

# %%
# delete null values

oscar_winners_2000_2023 = oscar_winners_2000_2023.dropna()

# %%
oscar_winners_2000_2023 = oscar_winners_2000_2023.drop(columns=['ceremony', 'category', 'name'])

# %%
# group by film and drop necessary columns

oscar_winners_2000_2023 = oscar_winners_2000_2023.groupby('film').agg(
    year_film=('year_film','first'), 
    year_ceremony=('year_ceremony','first'),
    wins=('winner','sum'),
    nominations=('winner','count')
).reset_index()

# %%
# adding boolean column winner

oscar_winners_2000_2023['winner'] = np.where(oscar_winners_2000_2023['wins'] > 0, True, False)

# %%
oscar_winners_2000_2023[oscar_winners_2000_2023['film'] == 'Inception']
# Out:
#           film  year_film  year_ceremony  wins  nominations  winner
# 493  Inception       2010           2011     4            8    True

# %%
# now, read the other imdb dataset to join with the kaggle
oscar_winners_2000_2023_imdb = pd.read_csv('/Users/paulettedvm/oscars_2000_2023_nominations_imdb.csv')

# %%
# join the two datasets (or concat ?? don't know)
# inner join to avoid NaN??
# or really i need to merge these two datasets based on the title column
oscar_winners_2000_2023_imdb = oscar_winners_2000_2023_imdb.fillna('Unknown')

# %%
oscar_winners_2000_2023_imdb = oscar_winners_2000_2023_imdb.rename(columns={'title':'film'})

# %%
oscar_winners_2000_2023_imdb
# Out:
#                                                   film  year runtime  \
# 0                                      The Dark Knight  2008  2h 32m
# 1                                            Inception  2010  2h 28m
# 2                                         Interstellar  2014  2h 49m
# 3    The Lord of the Rings: The Fellowship of the Ring  2001  2h 58m
# 4        The Lord of the Rings: The Return of the King  2003  3h 21m
# ..                                                 ...   ...     ...
# 972                    Scottsboro: An American Tragedy  2000  1h 24m
# 973                                Watani: My Homeland  2016  1h 16m
# 974                                         Open Heart  2013     40m
# 975                                             Legacy  2000  1h 30m
# 976                 On Tiptoe: Gentle Steps to Freedom  2000     58m
#
#     age_rating  star_rating  rating_count
# 0        PG-13          9.0       3000000
# 1        PG-13          8.8       2600000
# 2        PG-13          8.7       2300000
# 3        PG-13          8.9       2100000
# 4        PG-13          9.0       2100000
# ..         ...          ...           ...
# 972    Unknown          7.5           369
# 973    Unknown          7.4           305
# 974    Unknown          7.1           173
# 975  Not Rated          6.9           161
# 976    Unknown          7.5            56
#
# [977 rows x 6 columns]

# %%
# now merge oscar wins + imdb data 
# make it an inner join

merged_oscars_2000_2023 = pd.merge(oscar_winners_2000_2023, oscar_winners_2000_2023_imdb, on='film', how='inner')

# %%
# drop year column since it's duplicated w/ 'year_film'

merged_oscars_2000_2023 = merged_oscars_2000_2023.drop(columns=['year'])

# %%
merged_oscars_2000_2023
# Out:
#                                           film  year_film  year_ceremony  \
# 0                               102 Dalmatians       2000           2001
# 1                                           12       2007           2008
# 2                             12 Years a Slave       2013           2014
# 3                                    127 Hours       2010           2011
# 4    13 Hours: The Secret Soldiers of Benghazi       2016           2017
# ..                                         ...        ...            ...
# 910                                      Youth       2015           2016
# 911                                     Zelary       2003           2004
# 912                           Zero Dark Thirty       2012           2013
# 913                                   Zootopia       2016           2017
# 914                                   Zus & Zo       2002           2003
#
#      wins  nominations  winner runtime age_rating  star_rating  rating_count
# 0       0            1   False  1h 40m          G          4.8         40000
# 1       0            1   False  2h 39m      PG-13          7.5         16000
# 2       3            9    True  2h 14m          R          8.1        758000
# 3       0            6   False  1h 34m          R          7.5        411000
# 4       0            1   False  2h 24m          R          7.3        169000
# ..    ...          ...     ...     ...        ...          ...           ...
# 910     0            1   False   2h 4m          R          7.3         85000
# 911     0            1   False  2h 30m          R          7.5          3800
# 912     1            5    True  2h 37m          R          7.4        328000
# 913     1            1    True  1h 48m         PG          8.0        571000
# 914     0            1   False  1h 46m    Unrated          6.1          1700
#
# [915 rows x 10 columns]

# %%
# okay now that this is done, we can deal with the 2025 nominations dataset

# %%
oscar_2025_noms = pd.read_csv('/Users/paulettedvm/oscars_2025_nominations_imdb_filled.csv')

# %%
oscar_2025_noms = oscar_2025_noms.fillna('Unrated')

# %%
oscar_2025_noms.head()
# Out:
#             title  year_film runtime age_rating  star_rating  rating_count  \
# 0  Dune: Part Two       2024  2h 46m      PG-13          8.5        592000
# 1   The Substance       2024  2h 21m          R          7.3        232000
# 2  Alien: Romulus       2024  1h 59m          R          7.1        222000
# 3    Inside Out 2       2024  1h 36m         PG          7.6        203000
# 4    Gladiator II       2024  2h 28m          R          6.6        189000
#
#    nominations  year_ceremony
# 0            5           2025
# 1            5           2025
# 2            1           2025
# 3            1           2025
# 4            1           2025

# %%
# try my hand at modeling
# fit/build the model using the 2000_2023 data, test it and then use it on the 2025 data

# %%
y = merged_oscars_2000_2023.winner

# %%
features = ['nominations', 'star_rating', 'rating_count']
X = merged_oscars_2000_2023[features]

# i want to use 'wins as a feature but i can't because when i go to test it
# with the oscars 2025 data (what i actually want to predict) i can't 
# because the dataset doesn't have that feature... because it HASNT HAPPENED
# it's part of what i want to PREDICTTT

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# simple decision tree model

oscar_dt_model = DecisionTreeClassifier(random_state=1)
oscar_dt_model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=1)

# %%
y_pred = oscar_dt_model.predict(X_test)

# %%
acc_dt = accuracy_score(y_test, y_pred)
acc_dt
# Out:
# 0.7554585152838428

# %%
# decision tree model with limited leafs

leaf_limit_model = DecisionTreeClassifier(max_leaf_nodes=100)
leaf_limit_model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_leaf_nodes=100)

# %%
leaf_limit_pred = leaf_limit_model.predict(X_test)

# %%
acc_leaf_limit = accuracy_score(y_test, leaf_limit_pred)
acc_leaf_limit

# slightly more accuracy
# Out:
# 0.7816593886462883

# %%
ensemble_model = VotingClassifier(estimators=[
    ('xgb', XGBClassifier(n_estimators=200, max_depth=6, learning_rate=0.05)),
    ('rf', RandomForestClassifier(n_estimators=100, max_depth=10)),
    ('lr', LogisticRegression(max_iter=1000))
], voting='soft')
ensemble_model.fit(X_train, y_train)
# Out:
# VotingClassifier(estimators=[('xgb',
#                               XGBClassifier(base_score=None, booster=None,
#                                             callbacks=None,
#                                             colsample_bylevel=None,
#                                             colsample_bynode=None,
#                                             colsample_bytree=None, device=None,
#                                             early_stopping_rounds=None,
#                                             enable_categorical=False,
#                                             eval_metric=None,
#                                             feature_types=None, gamma=None,
#                                             grow_policy=None,
#                                             importance_type=None,
#                                             interaction_constraints=None,
#                                             learning_ra...
#                                             max_cat_threshold=None,
#                                             max_cat_to_onehot=None,
#                                             max_delta_step=None, max_depth=6,
#                                             max_leaves=None,
#                                             min_child_weight=None, missing=nan,
#                                             monotone_constraints=None,
#                                             multi_strategy=None,
#                                             n_estimators=200, n_jobs=None,
#                                             num_parallel_tree=None,
#                                             random_state=None, ...)),
#                              ('rf', RandomForestClassifier(max_depth=10)),
#                              ('lr', LogisticRegression(max_iter=1000))],
#                  voting='soft')

# %%
ensemble_y_pred = ensemble_model.predict(X_test)

# %%
ensemble_y_pred
# Out:
# array([False,  True, False, False, False,  True, False, False, False,
#        False, False, False, False, False,  True, False, False, False,
#        False, False, False,  True, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False,  True, False, False,  True, False,  True,
#        False, False, False,  True,  True, False,  True,  True, False,
#        False, False, False,  True, False,  True, False, False,  True,
#        False, False, False, False, False, False,  True, False, False,
#        False, False, False,  True, False, False, False, False,  True,
#        False, False, False, False, False,  True,  True, False, False,
#        False, False, False, False,  True, False, False, False,  True,
#        False, False, False, False,  True, False, False,  True,  True,
#        False,  True,  True, False,  True, False,  True, False,  True,
#        False, False, False, False,  True, False, False, False, False,
#        False, False, False, False, False, False,  True, False, False,
#        False, False, False, False,  True, False, False, False, False,
#        False,  True,  True,  True, False, False, False, False, False,
#        False, False, False, False, False, False, False,  True, False,
#        False,  True, False, False, False,  True, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False,  True, False, False,  True, False, False,  True, False,
#        False,  True, False, False, False, False,  True, False, False,
#        False, False, False, False, False, False, False, False, False,
#         True, False, False,  True,  True, False, False, False, False,
#         True,  True, False, False, False, False, False, False, False,
#        False,  True, False, False])

# %%
X_train
# Out:
#      nominations  star_rating  rating_count
# 790            2          8.0         87000
# 185            1          7.6        319000
# 363            2          7.9       1200000
# 888            1          7.4           305
# 531            6          7.4        150000
# ..           ...          ...           ...
# 767            3          7.2        257000
# 72             2          7.7        208000
# 908            1          7.5          2500
# 235            2          8.3       1100000
# 37             1          7.1        195000
#
# [686 rows x 3 columns]

# %%
accuracy_score(y_test, ensemble_y_pred)
# Out:
# 0.8253275109170306

# %%
## use trained ensemble model to predict 2025 winners

# %%
X_2025 = oscar_2025_noms[features]

# %%
y_2025_probs = ensemble_model.predict_proba(X_2025)[:, 1]

y_2025_preds = ensemble_model.predict(X_2025)

oscar_2025_noms['predicted_winner'] = y_2025_preds
oscar_2025_noms['winning_probability'] = y_2025_probs

# %%
oscar_2025_noms_sorted = oscar_2025_noms.sort_values(by='winning_probability', ascending=False)
oscar_2025_noms_sorted
# Out:
#                                     title  year_film runtime age_rating  \
# 1                           The Substance       2024  2h 21m          R
# 0                          Dune: Part Two       2024  2h 46m      PG-13
# 9                                Conclave       2024      2h         PG
# 8                                  Wicked       2024  2h 40m         PG
# 11                           Emilia Perez       2024  2h 12m          R
# 7                          The Wild Robot       2024  1h 42m         PG
# 10                                  Anora       2024  2h 19m          R
# 19                         I'm Still Here       2024  2h 17m      PG-13
# 20                          The Brutalist       2024  3h 34m          R
# 3                            Inside Out 2       2024  1h 36m         PG
# 6                               Nosferatu       2024  2h 12m          R
# 12                            A Real Pain       2024  1h 30m          R
# 16                     A Complete Unknown       2024  2h 21m          R
# 31            Soundtrack to a Coup d'Etat       2024  2h 30m    Unrated
# 14                                   Flow       2024  1h 25m         PG
# 39                       Death by Numbers       2024     33m    Unrated
# 27                            Nickel Boys       2024  2h 20m      PG-13
# 49                              Sing Sing       2023  1h 47m          R
# 28                          No Other Land       2024  1h 32m    Unrated
# 22                             Better Man       2024  2h 15m          R
# 2                          Alien: Romulus       2024  1h 59m          R
# 13                         The Apprentice       2024   2h 2m          R
# 23                      Memoir of a Snail       2024  1h 35m          R
# 30                      Black Box Diaries       2024  1h 42m    Unrated
# 15  Wallace & Gromit: Vengeance Most Fowl       2024  1h 22m         PG
# 41                               Incident       2023     30m    Unrated
# 4                            Gladiator II       2024  2h 28m          R
# 48    The Man Who Could Not Remain Silent       2024     13m    Unrated
# 33                          Porcelain War       2024  1h 27m          R
# 25               The Girl with the Needle       2024   2h 3m    Unrated
# 26                            September 5       2024  1h 35m          R
# 5       Kingdom of the Planet of the Apes       2024  2h 25m      PG-13
# 24             The Seed of the Sacred Fig       2024  2h 47m      PG-13
# 17                        A Different Man       2024  1h 52m          R
# 36                          Magic Candies       2024     21m    Unrated
# 46                        I'm Not a Robot       2023     22m    Unrated
# 44                                 A Lien       2023     15m    Unrated
# 42         Instruments of a Beating Heart       2024     23m    Unrated
# 29                              Sugarcane       2024  1h 47m          R
# 47                        The Last Ranger       2024     28m    Unrated
